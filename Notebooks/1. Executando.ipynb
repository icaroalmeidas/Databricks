# %%
dbutils.help()

# %%
# Visuzalizando o conteúdo do diretório
caminho = "dbfs:/Workspace/Repos/icaroalmeidas@hotmail.com/Dotabricks/Bike Store"
display(dbutils.fs.ls(caminho))

# %%
# Lendo arquivo CSV e defininido Dataframe
caminho_do_arquivo = "dbfs:/Workspace/Repos/icaroalmeidas@hotmail.com/Dotabricks/Bike Store/customers.csv"
df = spark.read.csv(caminho_do_arquivo, header=True, inferSchema=True)
df.display()
# header = True -> Indica que a primeira linha do arquivo é o cabeçalho
# inferSchema = True -> Indica que o Spark irá inferir o tipo de dados das colunas

# %%
df.show(10)

# %%
df.printSchema() # Mostra o esquema do DataFrame

# %%
df.columns

# %%
df.describe().display() # Mostra estatísticas descritivas do DataFrame

# %%
df.count()

# %%
#Ver algumas colunas sem salvar em um DF
colunas = ["customer_id", "first_name", "email", "state"]
df_filtrado = df.select(colunas)
display(df_filtrado)
